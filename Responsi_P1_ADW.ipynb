# %% [markdown]
# <a href="https://colab.research.google.com/github/fitridianamusa/Praktikum-Analisis-Deret-Waktu/blob/main/Responsi_P1_ADW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hallo")
# Out:
# hallo
